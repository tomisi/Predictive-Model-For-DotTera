# %%
# installing dependencies
import IPython
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt # used to plot the graph
# %matplotlib inline
from IPython import get_ipython
import warnings # surpress warning
warnings.filterwarnings("ignore")

# %%
# importing dataset
data = pd.read_csv("C:/Users/Hp/Downloads/dotTerra.csv")

# %%
# looking at the first 5 rows in the dataset
data.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
data.tail()
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee

# %%
#checking the amount of rows and columns 
data.shape
# Out:
# (2200, 8)

# %%
# data exploration
data.describe()
# Out:
#                  N            P            K  temperature     humidity  \
# count  2200.000000  2200.000000  2200.000000  2200.000000  2200.000000
# mean     50.551818    53.362727    48.149091    25.616244    71.481779
# std      36.917334    32.985883    50.647931     5.063749    22.263812
# min       0.000000     5.000000     5.000000     8.825675    14.258040
# 25%      21.000000    28.000000    20.000000    22.769375    60.261953
# 50%      37.000000    51.000000    32.000000    25.598693    80.473146
# 75%      84.250000    68.000000    49.000000    28.561654    89.948771
# max     140.000000   145.000000   205.000000    43.675493    99.981876
#
#                 ph     rainfall
# count  2200.000000  2200.000000
# mean      6.469480   103.463655
# std       0.773938    54.958389
# min       3.504752    20.211267
# 25%       5.971693    64.551686
# 50%       6.425045    94.867624
# 75%       6.923643   124.267508
# max       9.935091   298.560117

# %%
#checking for null values
data.isnull().sum()
# Out:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64

# %%
data.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
data.nunique()
# Out:
# N               137
# P               117
# K                73
# temperature    2200
# humidity       2200
# ph             2200
# rainfall       2200
# label            22
# dtype: int64

# %%
data['label'].unique()
# Out:
# array(['rice', 'maize', 'chickpea', 'kidneybeans', 'pigeonpeas',
#        'mothbeans', 'mungbean', 'blackgram', 'lentil', 'pomegranate',
#        'banana', 'mango', 'grapes', 'watermelon', 'muskmelon', 'apple',
#        'orange', 'papaya', 'coconut', 'cotton', 'jute', 'coffee'],
#       dtype=object)

# %%
data['label'].value_counts()
# Out:
# blackgram      100
# coconut        100
# mango          100
# cotton         100
# maize          100
# coffee         100
# grapes         100
# muskmelon      100
# jute           100
# mothbeans      100
# watermelon     100
# kidneybeans    100
# lentil         100
# pomegranate    100
# banana         100
# pigeonpeas     100
# papaya         100
# orange         100
# apple          100
# mungbean       100
# chickpea       100
# rice           100
# Name: label, dtype: int64

# %%
crop_summary=pd.pivot_table(data,index=['label'],aggfunc='mean') # finding the mean of each label/plant

# %%
crop_summary
# Out:
#                   K       N       P   humidity        ph    rainfall  \
# label
# apple        199.89   20.80  134.22  92.333383  5.929663  112.654779
# banana        50.05  100.23   82.01  80.358123  5.983893  104.626980
# blackgram     19.24   40.02   67.47  65.118426  7.133952   67.884151
# chickpea      79.92   40.09   67.79  16.860439  7.336957   80.058977
# coconut       30.59   21.98   16.93  94.844272  5.976562  175.686646
# coffee        29.94  101.20   28.74  58.869846  6.790308  158.066295
# cotton        19.56  117.77   46.24  79.843474  6.912675   80.398043
# grapes       200.11   23.18  132.53  81.875228  6.025937   69.611829
# jute          39.99   78.40   46.86  79.639864  6.732778  174.792798
# kidneybeans   20.05   20.75   67.54  21.605357  5.749411  105.919778
# lentil        19.41   18.77   68.36  64.804785  6.927932   45.680454
# maize         19.79   77.76   48.44  65.092249  6.245190   84.766988
# ...

# %%
data.columns
# Out:
# Index(['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall', 'label'], dtype='object')

# %%
# visualization
import plotly.express as px

# %%
fig = px.box(data, y="N" ,points="all")

fig.show()
# Out:
# <div>                            <div id="2b643427-7cbb-48ae-be21-06ce66e533f9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2b643427-7cbb-48ae-be21-06ce66e533f9")) {                    Plotly.newPlot(                        "2b643427-7cbb-48ae-be21-06ce66e533f9",                        [{"alignmentgroup":"True","boxpoints":"all","hovertemplate":"N=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x0":" ","xaxis":"x","y":[90,85,60,74,78,69,69,94,89,68,91,90,78,93,94,60,85,91,77,88,89,76,67,83,98,66,97,97,60,84,73,92,85,98,88,95,99,95,60,63,62,64,83,82,85,91,76,74,79,88,60,76,93,65,95,75,74,91,71,99,72,83,93,70,76,99,99,86,69,91,61,67,79,78,75,97,67,7
# ...

# %%
fig = px.box(data, y="humidity" ,points="all")

fig.show()
# Out:
# <div>                            <div id="5539ff63-e141-4ec6-ac73-8df79292b5a8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5539ff63-e141-4ec6-ac73-8df79292b5a8")) {                    Plotly.newPlot(                        "5539ff63-e141-4ec6-ac73-8df79292b5a8",                        [{"alignmentgroup":"True","boxpoints":"all","hovertemplate":"humidity=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x0":" ","xaxis":"x","y":[82.00274423,80.31964408,82.3207629,80.15836264,81.60487287,83.37011772,82.63941394,82.89408619,83.53521629999999,83.03322691,81.41753846,81.45061596,80.88684822,82.05687182,80.66385045,80.30025587,82.7883708,80.41817957,80.19
# ...

# %%
fig = px.box(data, y="rainfall" ,points="all")

fig.show()
# Out:
# <div>                            <div id="f6acf208-7a71-4a11-8189-ee640a86d660" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f6acf208-7a71-4a11-8189-ee640a86d660")) {                    Plotly.newPlot(                        "f6acf208-7a71-4a11-8189-ee640a86d660",                        [{"alignmentgroup":"True","boxpoints":"all","hovertemplate":"rainfall=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x0":" ","xaxis":"x","y":[202.9355362,226.6555374,263.96424759999996,242.86403419999996,262.7173405,251.05499980000002,271.3248604,241.97419490000001,230.4462359,221.2091958,264.6148697,250.0832336,284.4364567,185.2773389,209.58697080000002,231.086334
# ...

# %%
fig = px.box(data, y="ph" ,points="all")

fig.show()
# Out:
# <div>                            <div id="e58443b4-32a5-456e-8156-378b94961e67" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e58443b4-32a5-456e-8156-378b94961e67")) {                    Plotly.newPlot(                        "e58443b4-32a5-456e-8156-378b94961e67",                        [{"alignmentgroup":"True","boxpoints":"all","hovertemplate":"ph=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x0":" ","xaxis":"x","y":[6.502985292000001,7.038096361,7.840207144,6.980400905,7.628472891,7.073453503,5.70080568,5.718627177999999,6.685346424,6.336253525,5.386167788,7.50283396,5.108681786,6.98435366,6.94801983,7.042299068999999,6.2490506560000005,6.9708
# ...

# %%
fig = px.box(data, y="temperature" ,points="all")

fig.show()
# Out:
# <div>                            <div id="2911ba79-0fcd-4e7e-b78a-addf109e037b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2911ba79-0fcd-4e7e-b78a-addf109e037b")) {                    Plotly.newPlot(                        "2911ba79-0fcd-4e7e-b78a-addf109e037b",                        [{"alignmentgroup":"True","boxpoints":"all","hovertemplate":"temperature=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x0":" ","xaxis":"x","y":[20.87974371,24.01497622,25.66585205,23.79391957,21.32504158,21.94766735,22.30157427,22.17931888,26.79533926,25.62980105,25.59704938,24.8972823,24.958779,21.66628296,20.0454142,23.85724032,20.2801937,21.84106875,24.45802087
# ...

# %%
fig = px.box(data, y="P" ,points="all")

fig.show()
# Out:
# <div>                            <div id="17e0aba3-d89f-418c-a614-fa6ddd4a668e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("17e0aba3-d89f-418c-a614-fa6ddd4a668e")) {                    Plotly.newPlot(                        "17e0aba3-d89f-418c-a614-fa6ddd4a668e",                        [{"alignmentgroup":"True","boxpoints":"all","hovertemplate":"P=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x0":" ","xaxis":"x","y":[42,58,55,35,42,37,55,53,54,58,53,46,58,56,50,48,38,35,38,35,45,40,59,41,47,53,59,50,49,51,57,35,37,53,54,55,57,39,43,44,42,45,60,40,52,35,49,39,43,55,36,60,56,60,52,38,54,36,46,55,40,58,58,36,47,41,54,59,46,56,52,45,42,43,54,36,47,3
# ...

# %%
fig = px.box(data, y="K" ,points="all")

fig.show()
# Out:
# <div>                            <div id="ec348ed8-6e3f-4d6e-9531-2fa294a958fb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ec348ed8-6e3f-4d6e-9531-2fa294a958fb")) {                    Plotly.newPlot(                        "ec348ed8-6e3f-4d6e-9531-2fa294a958fb",                        [{"alignmentgroup":"True","boxpoints":"all","hovertemplate":"K=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x0":" ","xaxis":"x","y":[43,41,44,40,42,42,38,40,38,38,40,42,44,36,37,39,41,39,36,40,36,43,41,43,37,41,43,41,44,35,41,40,39,38,44,42,35,36,44,41,36,43,36,40,45,38,42,38,39,45,43,39,42,43,36,39,38,45,40,35,38,45,38,42,42,36,37,35,41,37,41,38,37,42,36,45,44,3
# ...

# %%
# Removing outliers 
df_boston = data
df_boston.colums =df_boston.columns
df_boston.head()

''' Detection '''
# IQR
Q1 = np.percentile(df_boston['rainfall'], 25,
                   interpolation = 'midpoint')

Q3 = np.percentile(df_boston['rainfall'], 75,
                   interpolation = 'midpoint')
IQR =Q3 -Q1

print("Old Shape: ", df_boston.shape)

# Upper bound
upper =np.where(df_boston['rainfall'] >= (Q3+1.5*IQR))
# Lower bound
lower = np.where(df_boston['rainfall'] <= (Q1-1.5*IQR))

''' Removing Outliers '''
df_boston.drop(upper[0], inplace = True)
df_boston.drop(lower[0], inplace = True)

print("New Shape: ", df_boston.shape)
# Out:
# Old Shape:  (2200, 8)
# New Shape:  (2101, 8)

# %%
data=df_boston

# %%
# Analysing data graphically 

plt.figure(figsize=(15,6))
sns.barplot(y='N' ,x='label' ,data=data,palette='deep')
plt.xticks(rotation=90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots

# %%
crop_summary=data.copy()

# %%
fig1= px.bar(crop_summary,x='label',y='N')
fig1.show()
# Out:
# <div>                            <div id="221aa94a-2a51-4bee-a8de-2470a9f994c9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("221aa94a-2a51-4bee-a8de-2470a9f994c9")) {                    Plotly.newPlot(                        "221aa94a-2a51-4bee-a8de-2470a9f994c9",                        [{"alignmentgroup":"True","hovertemplate":"label=%{x}<br>N=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["rice","rice","rice","rice","rice","rice","rice","rice","rice","rice","rice","rice","rice","rice","rice","rice","rice","rice","rice","rice","rice","rice","rice","rice","rice","rice","rice","rice","rice","rice","rice","rice","mai
# ...

# %%
fig1= px.bar(crop_summary,x='label',y='K')
fig1.show()
# Out:
# <div>                            <div id="323de5a5-ae76-4039-8af5-57e7d9ee0b99" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("323de5a5-ae76-4039-8af5-57e7d9ee0b99")) {                    Plotly.newPlot(                        "323de5a5-ae76-4039-8af5-57e7d9ee0b99",                        [{"alignmentgroup":"True","hovertemplate":"label=%{x}<br>K=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["rice","rice","rice","rice","rice","rice","rice","rice","rice","rice","rice","rice","rice","rice","rice","rice","rice","rice","rice","rice","rice","rice","rice","rice","rice","rice","rice","rice","rice","rice","rice","rice","mai
# ...

# %%
fig1= px.bar(crop_summary,x='label',y='P')
fig1.show()
# Out:
# <div>                            <div id="555adb3c-3905-4215-a452-2b4184235d1e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("555adb3c-3905-4215-a452-2b4184235d1e")) {                    Plotly.newPlot(                        "555adb3c-3905-4215-a452-2b4184235d1e",                        [{"alignmentgroup":"True","hovertemplate":"label=%{x}<br>P=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["rice","rice","rice","rice","rice","rice","rice","rice","rice","rice","rice","rice","rice","rice","rice","rice","rice","rice","rice","rice","rice","rice","rice","rice","rice","rice","rice","rice","rice","rice","rice","rice","mai
# ...

# %%
#import random
#from IPython.core.display import update_dispaly

# %%
data.corr()
# Out:
#                     N         P         K  temperature  humidity        ph  \
# N            1.000000 -0.237127 -0.139970     0.041633  0.189609  0.099238
# P           -0.237127  1.000000  0.737806    -0.133415 -0.111730 -0.146018
# K           -0.139970  0.737806  1.000000    -0.165188  0.198119 -0.174559
# temperature  0.041633 -0.133415 -0.165188     1.000000  0.203789 -0.021339
# humidity     0.189609 -0.111730  0.198119     0.203789  1.000000 -0.005955
# ph           0.099238 -0.146018 -0.174559    -0.021339 -0.005955  1.000000
# rainfall     0.003231 -0.046656 -0.042466    -0.039570  0.020846 -0.127166
#
#              rainfall
# N            0.003231
# P           -0.046656
# K           -0.042466
# temperature -0.039570
# humidity     0.020846
# ph          -0.127166
# rainfall     1.000000

# %%
# Heatmap 
fig, ax=plt.subplots(1,1,figsize=(15,9))
sns.heatmap(data.corr(),annot=True,cmap='Blues')
ax.set(xlabel='features')
ax.set(ylabel='features')

plt.title('correlation between different parameters',fontsize=15, c='black')
plt.show()

# %%
X=data.drop('label',axis=1)
y=data['label']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.30,
                                            shuffle=True,random_state=0)

# %%
import lightgbm as lgb
model = lgb.LGBMClassifier()
model.fit(X_train, y_train) # using the Lgbm model
# Out:
# LGBMClassifier()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score # Calculating accuracy score
accuracy=accuracy_score(y_pred, y_test)
print('LightGBN Model accuracy score: {0:0.4f}'.format(accuracy_score(y_test, y_pred)))
# Out:
# LightGBN Model accuracy score: 0.9889

# %%
# Calculating confudion matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(15,15))
sns.heatmap(cm,annot=True, fmt=" .0f", linewidths=.5, square = True, cmap = "Blues");
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Confusion Matrix - score:'+str(accuracy_score(y_test,y_pred))
plt.title(all_sample_title, size = 15);
plt.show()

# %%
from sklearn.metrics import classification_report
print(classification_report (y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        apple       1.00      1.00      1.00        29
#       banana       1.00      1.00      1.00        37
#    blackgram       1.00      0.97      0.99        34
#     chickpea       1.00      1.00      1.00        30
#      coconut       1.00      1.00      1.00        23
#       coffee       1.00      0.97      0.98        33
#       cotton       1.00      1.00      1.00        23
#       grapes       1.00      1.00      1.00        30
#         jute       0.84      1.00      0.91        31
#  kidneybeans       1.00      1.00      1.00        33
#       lentil       1.00      1.00      1.00        29
#        maize       0.97      1.00      0.98        28
#        mango       1.00      1.00      1.00        23
#    mothbeans       1.00      1.00      1.00        38
#     mungbean       1.00      1.00      1.00        30
#    muskmelon       1.00      1.00      1.00        32
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
Classifier=DecisionTreeClassifier(criterion='entropy',random_state=0)

# %%
Classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
y_pred=Classifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy=accuracy_score(y_test,y_pred)
print('decision tree model sccuracy score: {0:0.4f}'.format(accuracy_score(y_test,y_pred)))
# Out:
# decision tree model sccuracy score: 0.9905

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(15,15))
sns.heatmap(cm,annot=True, fmt=" .0f", linewidths=.5, square = True, cmap = "Blues");
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Confusion Matrix - score:'+str(accuracy_score(y_test,y_pred))
plt.title(all_sample_title, size = 15);
plt.show()

# %%
from sklearn.metrics import classification_report
print(classification_report (y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        apple       1.00      1.00      1.00        29
#       banana       1.00      1.00      1.00        37
#    blackgram       1.00      0.97      0.99        34
#     chickpea       1.00      1.00      1.00        30
#      coconut       1.00      1.00      1.00        23
#       coffee       1.00      1.00      1.00        33
#       cotton       0.96      1.00      0.98        23
#       grapes       1.00      1.00      1.00        30
#         jute       0.94      0.94      0.94        31
#  kidneybeans       1.00      1.00      1.00        33
#       lentil       1.00      1.00      1.00        29
#        maize       0.96      0.96      0.96        28
#        mango       1.00      1.00      1.00        23
#    mothbeans       1.00      1.00      1.00        38
#     mungbean       1.00      1.00      1.00        30
#    muskmelon       1.00      1.00      1.00        32
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
Classifier=DecisionTreeClassifier(criterion='entropy',random_state=0)

# %%
# classifier_lr=LogisticRegression(random_state=0)

# %%
Classifier.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
y_pred=classifier_lr.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy=accuracy_score(y_pred, y_test)
print("The Logistic Regression Model Accuracy Score: {0:0.4f}".format(accuracy_score(y_test, y_pred)))
# Out:
# The Logistic Regression Model Accuracy Score: 0.9445

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(15,15))
sns.heatmap(cm,annot=True, fmt=" .0f", linewidths=.5, square = True, cmap = "Blues");
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Confusion Matrix - score:'+str(accuracy_score(y_test,y_pred))
plt.title(all_sample_title, size = 15);
plt.show()

# %%
from sklearn.metrics import classification_report
print(classification_report (y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        apple       1.00      1.00      1.00        29
#       banana       1.00      1.00      1.00        37
#    blackgram       0.87      0.79      0.83        34
#     chickpea       1.00      1.00      1.00        30
#      coconut       0.92      1.00      0.96        23
#       coffee       1.00      1.00      1.00        33
#       cotton       0.78      0.91      0.84        23
#       grapes       1.00      1.00      1.00        30
#         jute       0.81      0.94      0.87        31
#  kidneybeans       1.00      1.00      1.00        33
#       lentil       0.88      1.00      0.94        29
#        maize       0.81      0.79      0.80        28
#        mango       1.00      1.00      1.00        23
#    mothbeans       0.91      0.76      0.83        38
#     mungbean       0.97      1.00      0.98        30
#    muskmelon       1.00      1.00      1.00        32
# ...

# %%
from sklearn.linear_model import LogisticRegression

# %%
classifier_lr=LogisticRegression(random_state=0)

# %%
classifier_lr.fit(X_train,y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
y_pred=classifier_lr.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy=accuracy_score(y_pred, y_test)
print("The Logistic Regression Model Accuracy Score: {0:0.4f}".format(accuracy_score(y_test, y_pred)))
# Out:
# The Logistic Regression Model Accuracy Score: 0.9445

# %%
from sklearn.metrics import classification_report
print(classification_report (y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        apple       1.00      1.00      1.00        29
#       banana       1.00      1.00      1.00        37
#    blackgram       0.87      0.79      0.83        34
#     chickpea       1.00      1.00      1.00        30
#      coconut       0.92      1.00      0.96        23
#       coffee       1.00      1.00      1.00        33
#       cotton       0.78      0.91      0.84        23
#       grapes       1.00      1.00      1.00        30
#         jute       0.81      0.94      0.87        31
#  kidneybeans       1.00      1.00      1.00        33
#       lentil       0.88      1.00      0.94        29
#        maize       0.81      0.79      0.80        28
#        mango       1.00      1.00      1.00        23
#    mothbeans       0.91      0.76      0.83        38
#     mungbean       0.97      1.00      0.98        30
#    muskmelon       1.00      1.00      1.00        32
# ...

# %%
X_test[0:1]
# Out:
#        N    P    K  temperature   humidity        ph   rainfall
# 1203  36  125  196    37.465668  80.659687  6.155261  66.838723

# %%
# from sklearn.tree import DecisionTreeClassifier
# Classifier=DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
result=Classifier.predict(X_test[0:1])

# %%
result
# Out:
# array(['grapes'], dtype=object)

# %%
y_test[0:1]
# Out:
# 1203    grapes
# Name: label, dtype: object
